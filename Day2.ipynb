# %%
a = 3
b = 5
c = 8
d = 9
m = (a+b+c+d)/4
print(m)
# Out:
# 6.25

# %%
lst = [1, 2, 3, 4]
n = len(lst)
if n % 2 == 0:
    m=(lst[n//2 - 1]+lst[n//2])/2
else:
    m=lst[n//2]
print("Median =", m)
# Out:
# Median = 2.5

# %%
l=[1,2,3,3,4]
m=statistics.mode(lst)
print("Mode:", m)
# Out:
# Mode: 3

# %%
#variance
s= [80,90,70,90,80]
m= sum(s)/len(s)
v= sum((x-m)**2 for x in s)/len(s)
print(v)
# Out:
# 56.0
